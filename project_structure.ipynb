# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# #### The age of the company you are applying the job for is what you call the "Age of the Company"
# #### People in USA embassy use this ML model to check if the particular candidate is eligible for VISA or not.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Database we use is Mongodb
#
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Mongodb Atlas
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### Project description

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# 1) Download dataset from https://www.kaggle.com/datasets/moro23/easyvisa-dataset
# 2) Push to mongodb using pymongo api
# 3) Fetch the pushed data using pymongo api

# %% [markdown]
# ## STRUCTURE
#
# We have a cluster and inside that cluster can have many dbs but for now we have a db named "US_VISA" and inside that we have collections "us_visa_collection" equivalent to tables in SQL DBs, and each collection has documents which are equivalent to rows in SQL DBs and they are key value pairs
#
# ![image.png](attachment:image.png)
#
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-4.png](attachment:image-4.png)
